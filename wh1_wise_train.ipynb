# %% [markdown]
# ##### Import dependencies

# %%
import numpy as np
import pandas as pd
from numpy.fft import *
import shutil
import os
import os
import glob
from tensorflow.keras.models import load_model
from tqdm.notebook import tqdm, trange

# from RNN import RNN
from Transformer import Transformer
#from CNN import CNN

from utils import series_to_supervised

from utils import rmse, smape, coeff_determination

# %%
MODEL_PATH = 'wh_wise_best_models/'
TRAIN_PATH = '../dataset/wh_wise_data/train/'
TEST_PATH = '../dataset/wh_wise_data/test/'

# %% [markdown]
# ##### Preprocess DataFrame

# %%
def preprocess1(df):
    df['date'] = pd.to_datetime(df['date'], dayfirst=True)
    df.set_index(['date'], inplace=True)
    df.drop(columns=['Unnamed: 0', 'wh_id'], inplace=True)
    return df

# %%
def preprocess2(daily_data):
    daily_data['day'] = pd.DatetimeIndex(daily_data.index).day
    daily_data['weekday'] = ((pd.DatetimeIndex(daily_data.index).dayofweek) // 5 == 1).astype(float)
    daily_data['season'] = [month%12 // 3 + 1 for month in pd.DatetimeIndex(daily_data.index).month]
    daily_data.drop(columns='weekday', inplace=True)
    return daily_data

# %% [markdown]
# ##### Module to filter noise

# %%
def filter_signal(signal, threshold=3e3):
    fourier = rfft(signal)
    frequencies = rfftfreq(signal.size, d=20e-3/(signal.size))
    fourier[frequencies > threshold] = 0
    return irfft(fourier)

# %% [markdown]
# ##### Train-Test Split

# %%
def tt_split(daily_data):
    look_back = 7
    n_features = daily_data.shape[1]

    # Walk-forward data split to avoid data leakage
    X_train, y_train, X_test, y_test, scale_X = series_to_supervised(daily_data, train_size=0.8, n_in=look_back, n_out=7, target_column='sales', dropnan=True, scale_X=True)

    # reshape input to be 3D [samples, timesteps, features]
    X_train_reshaped = X_train.values.reshape((-1,look_back,n_features))
    X_test_reshaped = X_test.values.reshape((-1,look_back,n_features))

    y_train_reshaped = y_train.values
    y_test_reshaped = y_test.values
    return X_train, X_train_reshaped, X_test, X_test_reshaped, y_train, y_train_reshaped, y_test, y_test_reshaped

# %% [markdown]
# ##### Module to Train the transformer

# %%
def train_trans(id, X_train_reshaped, y_train_reshaped, X_test_reshaped, y_test_reshaped):
    tr = Transformer()
    tr.train(X_train_reshaped,y_train_reshaped)
    _, rmse_result, mae_result, smape_result, r2_result = tr.evaluate(X_test_reshaped,y_test_reshaped)
    best_model = sorted(os.listdir('checkpoint'), reverse=True)[0]
    src = os.path.join('checkpoint', best_model)
    target = os.path.join(MODEL_PATH, 'wh_'+str(id)+'.hdf5')
    shutil.copy2(src, target)

# %% [markdown]
# ##### Iterating through warehouses

# %%
whlst = os.listdir(TRAIN_PATH)
start = 55
end = 112

# %%
whlst[55]
# Out:
# 'train_wh_1079.csv'

# %%
for wh in tqdm(whlst[start:end]):
    id = int(wh.split('_')[-1][:-4])
    df_path = os.path.join(TRAIN_PATH, wh)
    df = pd.read_csv(df_path)
    df = preprocess1(df)
    x = filter_signal(df['sales'])
    df = df[:-1] 
    df['sales']=x
    daily_data = preprocess2(df)
    X_train, X_train_reshaped, X_test, X_test_reshaped, y_train, y_train_reshaped, y_test, y_test_reshaped = tt_split(daily_data)
    train_trans(id, X_train_reshaped, y_train_reshaped, X_test_reshaped, y_test_reshaped)
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 4)]       0           []
#
#  layer_normalization (LayerNorm  (None, 7, 4)        8           ['input_1[0][0]']
#  alization)
#
#  multi_head_attention (MultiHea  (None, 7, 4)        19460       ['layer_normalization[0][0]',
#  dAttention)                                                      'layer_normalization[0][0]']
#
#  dropout (Dropout)              (None, 7, 4)         0           ['multi_head_attention[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 7, 4)        0           ['dropout[0][0]',
#  da)                                                              'input_1[0][0]']
#
#  layer_normalization_1 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add[0][0]']
#  rmalization)
#
#  conv1d (Conv1D)                (None, 7, 4)         20          ['layer_normalization_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 7, 4)         0           ['conv1d[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 7, 4)         20          ['dropout_1[0][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 7, 4)        0           ['conv1d_1[0][0]',
#  mbda)                                                            'tf.__operators__.add[0][0]']
#
#  layer_normalization_2 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_1[0][0]']
#  rmalization)
#
#  multi_head_attention_1 (MultiH  (None, 7, 4)        19460       ['layer_normalization_2[0][0]',
#  eadAttention)                                                    'layer_normalization_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 7, 4)         0           ['multi_head_attention_1[0][0]']
#
#  tf.__operators__.add_2 (TFOpLa  (None, 7, 4)        0           ['dropout_2[0][0]',
#  mbda)                                                            'tf.__operators__.add_1[0][0]']
#
#  layer_normalization_3 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_2[0][0]']
#  rmalization)
#
#  conv1d_2 (Conv1D)              (None, 7, 4)         20          ['layer_normalization_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 7, 4)         0           ['conv1d_2[0][0]']
#
#  conv1d_3 (Conv1D)              (None, 7, 4)         20          ['dropout_3[0][0]']
#
#  tf.__operators__.add_3 (TFOpLa  (None, 7, 4)        0           ['conv1d_3[0][0]',
#  mbda)                                                            'tf.__operators__.add_2[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_3[0][0]']
#  rmalization)
#
#  multi_head_attention_2 (MultiH  (None, 7, 4)        19460       ['layer_normalization_4[0][0]',
#  eadAttention)                                                    'layer_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 7, 4)         0           ['multi_head_attention_2[0][0]']
#
#  tf.__operators__.add_4 (TFOpLa  (None, 7, 4)        0           ['dropout_4[0][0]',
#  mbda)                                                            'tf.__operators__.add_3[0][0]']
#
#  layer_normalization_5 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_4[0][0]']
#  rmalization)
#
#  conv1d_4 (Conv1D)              (None, 7, 4)         20          ['layer_normalization_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 7, 4)         0           ['conv1d_4[0][0]']
#
#  conv1d_5 (Conv1D)              (None, 7, 4)         20          ['dropout_5[0][0]']
#
#  tf.__operators__.add_5 (TFOpLa  (None, 7, 4)        0           ['conv1d_5[0][0]',
#  mbda)                                                            'tf.__operators__.add_4[0][0]']
#
#  layer_normalization_6 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_5[0][0]']
#  rmalization)
#
#  multi_head_attention_3 (MultiH  (None, 7, 4)        19460       ['layer_normalization_6[0][0]',
#  eadAttention)                                                    'layer_normalization_6[0][0]']
#
#  dropout_6 (Dropout)            (None, 7, 4)         0           ['multi_head_attention_3[0][0]']
#
#  tf.__operators__.add_6 (TFOpLa  (None, 7, 4)        0           ['dropout_6[0][0]',
#  mbda)                                                            'tf.__operators__.add_5[0][0]']
#
#  layer_normalization_7 (LayerNo  (None, 7, 4)        8           ['tf.__operators__.add_6[0][0]']
#  rmalization)
#
#  conv1d_6 (Conv1D)              (None, 7, 4)         20          ['layer_normalization_7[0][0]']
#
#  dropout_7 (Dropout)            (None, 7, 4)         0           ['conv1d_6[0][0]']
#
#  conv1d_7 (Conv1D)              (None, 7, 4)         20          ['dropout_7[0][0]']
#
#  tf.__operators__.add_7 (TFOpLa  (None, 7, 4)        0           ['conv1d_7[0][0]',
#  mbda)                                                            'tf.__operators__.add_6[0][0]']
#
#  global_average_pooling1d (Glob  (None, 7)           0           ['tf.__operators__.add_7[0][0]']
#  alAveragePooling1D)
#
#  dense (Dense)                  (None, 128)          1024        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
#  dropout_8 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 7)            903         ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 79,991
# Trainable params: 79,991
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/200
# 10/10 [==============================] - ETA: 0s - loss: 147776.8281 - rmse: 382.2676 - mae: 252.0549 - smape: 99.6312 - coeff_determination: -0.7718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 1: loss improved from inf to 147776.82812, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 10s 356ms/step - loss: 147776.8281 - rmse: 382.2676 - mae: 252.0549 - smape: 99.6312 - coeff_determination: -0.7718
# Epoch 2/200
# 10/10 [==============================] - ETA: 0s - loss: 147734.0312 - rmse: 383.5423 - mae: 251.9642 - smape: 99.3661 - coeff_determination: -0.7589WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 2: loss improved from 147776.82812 to 147734.03125, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 345ms/step - loss: 147734.0312 - rmse: 383.5423 - mae: 251.9642 - smape: 99.3661 - coeff_determination: -0.7589
# Epoch 3/200
# 10/10 [==============================] - ETA: 0s - loss: 147670.5000 - rmse: 382.7969 - mae: 251.8498 - smape: 99.0473 - coeff_determination: -0.7696WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 3: loss improved from 147734.03125 to 147670.50000, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 306ms/step - loss: 147670.5000 - rmse: 382.7969 - mae: 251.8498 - smape: 99.0473 - coeff_determination: -0.7696
# Epoch 4/200
# 10/10 [==============================] - ETA: 0s - loss: 147592.0469 - rmse: 383.9473 - mae: 251.7011 - smape: 98.6084 - coeff_determination: -0.7566WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 4: loss improved from 147670.50000 to 147592.04688, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 349ms/step - loss: 147592.0469 - rmse: 383.9473 - mae: 251.7011 - smape: 98.6084 - coeff_determination: -0.7566
# Epoch 5/200
# 10/10 [==============================] - ETA: 0s - loss: 147497.2969 - rmse: 381.8100 - mae: 251.5258 - smape: 98.1436 - coeff_determination: -0.7719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 5: loss improved from 147592.04688 to 147497.29688, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 343ms/step - loss: 147497.2969 - rmse: 381.8100 - mae: 251.5258 - smape: 98.1436 - coeff_determination: -0.7719
# Epoch 6/200
# 10/10 [==============================] - ETA: 0s - loss: 147356.6406 - rmse: 381.4184 - mae: 251.2962 - smape: 97.5563 - coeff_determination: -0.7690WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 6: loss improved from 147497.29688 to 147356.64062, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s
saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 345ms/step - loss: 26724.5254 - rmse: 162.0390 - mae: 104.5058 - smape: 42.2142 - coeff_determination: 0.6757
# Epoch 60/200
# 10/10 [==============================] - ETA: 0s - loss: 27597.0859 - rmse: 165.1950 - mae: 103.2803 - smape: 39.0949 - coeff_determination: 0.6671WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 60: loss did not improve from 26724.52539
# 10/10 [==============================] - 3s 322ms/step - loss: 27597.0859 - rmse: 165.1950 - mae: 103.2803 - smape: 39.0949 - coeff_determination: 0.6671
# Epoch 61/200
# 10/10 [==============================] - ETA: 0s - loss: 26119.9492 - rmse: 160.0217 - mae: 100.0827 - smape: 36.2391 - coeff_determination: 0.6889WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 61: loss improved from 26724.52539 to 26119.94922, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# 10/10 [==============================] - 3s 343ms/step - loss: 26119.9492 - rmse: 160.0217 - mae: 100.0827 - smape: 36.2391 - coeff_determination: 0.6889
# Epoch 62/200
# 10/10 [==============================] - ETA: 0s - loss: 26499.9492 - rmse: 162.6388 - mae: 99.1954 - smape: 34.1526 - coeff_determination: 0.6697WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 62: loss did not improve from 26119.94922
# 10/10 [==============================] - 3s 321ms/step - loss: 26499.9492 - rmse: 162.6388 - mae: 99.1954 - smape: 34.1526 - coeff_determination: 0.6697
# Epoch 63/200
# 10/10 [==============================] - ETA: 0s - loss: 23989.9375 - rmse: 153.2758 - mae: 95.1957 - smape: 33.5365 - coeff_determination: 0.7124WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 63: loss improved from 26119.94922 to 23989.93750, saving model to checkpoint\Transformer_best15102022_09_54_24.hdf5
# ...
# Epoch 100/200
# 10/10 [==============================] - ETA: 0s - loss: 9280.8291 - rmse: 95.6763 - mae: 58.3700 - smape: 43.8052 - coeff_determination: 0.1384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 100: loss did not improve from 9122.01562
# 10/10 [==============================] - 4s 354ms/step - loss: 9280.8291 - rmse: 95.6763 - mae: 58.3700 - smape: 43.8052 - coeff_determination: 0.1384
# Epoch 101/200
# 10/10 [==============================] - ETA: 0s - loss: 9271.1064 - rmse: 93.9603 - mae: 59.8684 - smape: 45.1765 - coeff_determination: 0.1222WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 101: loss did not improve from 9122.01562
# 10/10 [==============================] - 4s 376ms/step - loss: 9271.1064 - rmse: 93.9603 - mae: 59.8684 - smape: 45.1765 - coeff_determination: 0.1222
# Epoch 102/200
# 10/10 [==============================] - ETA: 0s - loss: 9673.9180 - rmse: 96.0413 - mae: 59.7711 - smape: 44.9902 - coeff_determination: 0.0671WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 102: loss did not improve from 9122.01562
# 10/10 [==============================] - 4s 345ms/step - loss: 9673.9180 - rmse: 96.0413 - mae: 59.7711 - smape: 44.9902 - coeff_determination: 0.0671
# Epoch 103/200
# 10/10 [==============================] - ETA: 0s - loss: 9331.7480 - rmse: 94.9072 - mae: 57.8311 - smape: 43.9397 - coeff_determination: 0.1100WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 103: loss did not improve from 9122.01562
# 10/10 [==============================] - 3s 340ms/step - loss: 9331.7480 - rmse: 94.9072 - mae: 57.8311 - smape: 43.9397 - coeff_determination: 0.1100
# Epoch 104/200
# 10/10 [==============================] - ETA: 0s - loss: 9411.1895 - rmse: 95.7156 - mae: 57.9646 - smape: 43.8323 - coeff_determination: 0.1071WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 104: loss did not improve from 9122.01562
# 10/10 [==============================] - 4s 357ms/step - loss: 9411.1895 - rmse: 95.7156 - mae: 57.9646 - smape: 43.8323 - coeff_determination: 0.1071
# Epoch 105/200
# 10/10 [==============================] - ETA: 0s - loss: 9364.6523 - rmse: 96.3029 - mae: 58.8279 - smape: 44.6603 - coeff_determination: 0.1448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 105: loss did not improve from 9122.01562
# 10/10 [==============================] - 3s 344ms/step - loss: 9364.6523 - rmse: 96.3029 - mae: 58.8279 - smape: 44.6603 - coeff_determination: 0.1448
# Epoch 106/200
# 10/10 [==============================] - ETA: 0s - loss: 9303.2568 - rmse: 95.5056 - mae: 58.7774 - smape: 44.7831 - coeff_determination: 0.1530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 106: loss did not improve from 9122.01562
# 10/10 [==============================] - 3s 332ms/step - loss: 9303.2568 - rmse: 95.5056 - mae: 58.7774 - smape: 44.7831 - coeff_determination: 0.1530
# Epoch 107/200
# 10/10 [==============================] - ETA: 0s - loss: 9165.4150 - rmse: 95.2292 - mae: 58.5523 - smape: 44.3375 - coeff_determination: 0.1767WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 107: loss did not improve from 9122.01562
# 10/10 [==============================] - 3s 338ms/step - loss: 9165.4150 - rmse: 95.2292 - mae: 58.5523 - smape: 44.3375 - coeff_determination: 0.1767
# Epoch 108/200
# 10/10 [==============================] - ETA: 0s - loss: 9182.0049 - rmse: 93.2038 - mae: 58.1853 - smape: 44.3790 - coeff_determination: 0.0540WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 108: loss did not improve from 9122.01562
# 10/10 [==============================] - 4s 343ms/step - loss: 9182.0049 - rmse: 93.2038 - mae: 58.1853 - smape: 44.3790 - coeff_determination: 0.0540
# Epoch 109/200
# 10/10 [==============================] - ETA: 0s - loss: 9000.3916 - rmse: 92.7124 - mae: 57.2979 - smape: 43.8140 - coeff_determination: 0.1248WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 109: loss improved from 9122.01562 to 9000.39160, saving model to checkpoint\Transformer_best15102022_10_41_40.hdf5
# 10/10 [==============================] - 4s 383ms/step - loss: 9000.3916 - rmse: 92.7124 - mae: 57.2979 - smape: 43.8140 - coeff_determination: 0.1248
# Epoch 110/200
# 10/10 [==============================] - ETA: 0s - loss: 9022.0439 - rmse: 93.7248 - mae: 57.7638 - smape: 44.4248 - coeff_determination: 0.1513WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 110: loss did not improve from 9000.39160
# 10/10 [==============================] - 4s 383ms/step - loss: 9022.0439 - rmse: 93.7248 - mae: 57.7638 - smape: 44.4248 - coeff_determination: 0.1513
# Epoch 111/200
# 10/10 [==============================] - ETA: 0s - loss: 9065.0996 - rmse: 93.3974 - mae: 57.9301 - smape: 44.6722 - coeff_determination: 0.0941WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 111: loss did not improve from 9000.39160
# 10/10 [==============================] - 4s 389ms/step - loss: 9065.0996 - rmse: 93.3974 - mae: 57.9301 - smape: 44.6722 - coeff_determination: 0.0941
# Epoch 112/200
# 10/10 [==============================] - ETA: 0s - loss: 9380.6953 - rmse: 94.7247 - mae: 57.3321 - smape: 43.8001 - coeff_determination: 0.1316WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 112: loss did not improve from 9000.39160
# 10/10 [==============================] - 4s 377ms/step - loss: 9380.6953 - rmse: 94.7247 - mae: 57.3321 - smape: 43.8001 - coeff_determination: 0.1316
# Epoch 113/200
# 10/10 [==============================] - ETA: 0s - loss: 8817.2227 - rmse: 93.3931 - mae: 57.4321 - smape: 43.7826 - coeff_determination: 0.2188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 113: loss improved from 9000.39160 to 8817.22266, saving model to checkpoint\Transformer_best15102022_10_41_40.hdf5
# 10/10 [==============================] - 4s 398ms/step - loss: 8817.2227 - rmse: 93.3931 - mae: 57.4321 - smape: 43.7826 - coeff_determination: 0.2188
# Epoch 114/200
# 10/10 [==============================] - ETA: 0s - loss: 9107.8770 - rmse: 94.2323 - mae: 58.1686 - smape: 44.3420 - coeff_determination: 0.1496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,rmse,mae,smape,coeff_determination
#
# Epoch 114: loss did not improve from 8817.22266
# 10/10 [==============================] - 3s 347ms/step - loss: 9107.8770 - rmse: 94.2323 - mae: 58.1686 - smape: 44.3420 - coeff_determination: 0.1496
# Epoch 115/200
#  3/10 [========>.....................] - ETA: 2s - loss: 10636.5029 - rmse: 97.8132 - mae: 61.3896 - smape: 46.8729 - coeff_determination: 0.1775
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# d:\sys files\documents\sigmoid\Multivariate-time-series-forecasting-keras-main\wh1_wise_train.ipynb Cell 16 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=8'>9</a> daily_data = preprocess2(df)
#      <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> X_train, X_train_reshaped, X_test, X_test_reshaped, y_train, y_train_reshaped, y_test, y_test_reshaped = tt_split(daily_data)
# ---> <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=10'>11</a> train_trans(id, X_train_reshaped, y_train_reshaped, X_test_reshaped, y_test_reshaped)
#
# d:\sys files\documents\sigmoid\Multivariate-time-series-forecasting-keras-main\wh1_wise_train.ipynb Cell 16 in train_trans(id, X_train_reshaped, y_train_reshaped, X_test_reshaped, y_test_reshaped)
#       <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> def train_trans(id, X_train_reshaped, y_train_reshaped, X_test_reshaped, y_test_reshaped):
#       <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=1'>2</a>     tr = Transformer()
# ----> <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a>     tr.train(X_train_reshaped,y_train_reshaped)
#       <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a>     _, rmse_result, mae_result, smape_result, r2_result = tr.evaluate(X_test_reshaped,y_test_reshaped)
#       <a href='vscode-notebook-cell:/d%3A/sys%20files/documents/sigmoid/Multivariate-time-series-forecasting-keras-main/wh1_wise_train.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a>     best_model = sorted(os.listdir('checkpoint'), reverse=True)[0]
#
# File d:\sys files\documents\sigmoid\Multivariate-time-series-forecasting-keras-main\Transformer.py:141, in Transformer.train(self, X_train, y_train, epochs, batch_size)
#     138 filepath = self.checkpoint_dir+"/Transformer_best"+datetime.now().strftime('%d%m%Y_%H_%M_%S')+".hdf5"
#     139 checkpoint = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
# --> 141 callback_history = self.model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size,
#     142                      #validation_split=0.2,
#     143                      verbose=1,
#     144                      callbacks=[early_stopping_monitor, checkpoint], workers=-1)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File d:\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
#******** train 1017 ********

# %%
for wh in os.listdir(TEST_PATH):
    id = int(wh.split('_')[-1][:-4])
    model_path = os.path.join(MODEL_PATH, f'wh_{id}.hdf5')
    model = load_model(model_path, custom_objects={'rmse':rmse, 'smape':smape, 'coeff_determination':coeff_determination})
